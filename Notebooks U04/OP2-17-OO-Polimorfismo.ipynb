# %% [markdown]
# <img src='op2-u04.png'/>
# <h2><font color='#7F0000'>OP2-OO-17-Polimorfismo</font></h2>

# %% [markdown]
# <table width='100%'>
#     <tbody>
#         <tr>
#             <td width='33%' style='text-align: left; background-color: #DDDDDD; vertical-align: top;'>Notebook Anterior<br><a href="OP2-16-OO-Heranca.ipynb">OP2-16-OO-Heranca</a></td>
#             <td width='34%' style='text-align: left; background-color: #DDDDDD; vertical-align: top;'>&nbsp;<br/>
#             </td>
#             <td width='33%'style='text-align: left; background-color: #DDDDDD; vertical-align: top;'>Próximo Notebook<br/><a href="OP2-18-OO-Aplicacoes.ipynb">OP2-18-OO-Aplicacoes</a></td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# ## ?

# %%
# 
# 
# 
#

# %% [markdown]
# <h4>Considerações adicionais:</h4>
# <ul>
#     <li>Python também suporta a herança múltipla, por meio da qual uma classe pode ser descendente de duas ou mais classes. Como o uso de herança múltipla é relativamente limitado (e controverso), este tópico não será tratado nesta oficina.</li>
# </ul>

# %% [markdown]
# ### FIM
# ### <a href="http://github.com/pjandl/opy2">Oficina Python Intermediário</a>
